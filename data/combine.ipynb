# %%
import pandas as pd
import os

# List of file names
files = [
    "barcelona_weekdays.csv", "budapest_weekends.csv", "london_weekends.csv", "vienna_weekdays.csv",
    "amsterdam_weekdays.csv", "barcelona_weekends.csv", "paris_weekdays.csv", "vienna_weekends.csv",
    "amsterdam_weekends.csv", "berlin_weekdays.csv", "lisbon_weekdays.csv", "paris_weekends.csv",
    "athens_weekdays.csv", "berlin_weekends.csv", "lisbon_weekends.csv", "rome_weekdays.csv",
    "athens_weekends.csv", "budapest_weekdays.csv", "london_weekdays.csv", "rome_weekends.csv"
]

# Directory containing your data files
directory = "../data/"

# Initialize an empty list to hold dataframes
dataframes = []

# Read each file and append to the list
for file in files:
    # Create the full path to the file
    file_path = os.path.join(directory, file)
    # Read the CSV file
    df = pd.read_csv(file_path)
    # Optionally, add a column to identify the file (e.g., city and weekday/weekend)
    city, period = file.replace('.csv', '').rsplit('_', 1)
    df['city'] = city.capitalize()
    df['period'] = period.capitalize()
    # Append the dataframe to the list
    dataframes.append(df)

# Concatenate all dataframes into one
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_csv_path = os.path.join(directory, 'combined_data.csv')
combined_df.to_csv(combined_csv_path, index=False)

print(f'Combined file created at: {combined_csv_path}')
# Out:
# Combined file created at: ../data/combined_data.csv

# %%
combined_df
# Out:
#        Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0               0  474.317499  Entire home/apt        False         False
# 1               1  169.897829     Private room        False          True
# 2               2  161.984779     Private room        False          True
# 3               3  367.956804  Entire home/apt        False         False
# 4               4  196.895292     Private room        False          True
# ...           ...         ...              ...          ...           ...
# 51702        4530  413.812452  Entire home/apt        False         False
# 51703        4531  582.376733  Entire home/apt        False         False
# 51704        4532  878.591635  Entire home/apt        False         False
# 51705        4533  447.244757  Entire home/apt        False         False
# 51706        4534  265.821897  Entire home/apt        False         False
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                  4.0              False      0    1                10.0
# 1                  2.0               True      1    0                10.0
# 2                  4.0              False      0    1                 9.0
# 3                  3.0              False      0    1                10.0
# 4                  3.0              False      1    0                 9.0
# ...                ...                ...    ...  ...                 ...
# 51702              4.0              False      0    1                10.0
# 51703              6.0               True      0    1                10.0
# 51704              6.0               True      1    0                10.0
# 51705              4.0               True      1    0                10.0
# 51706              6.0              False      0    1                10.0
#
#        ...      dist  metro_dist   attr_index  attr_index_norm   rest_index  \
# 0      ...  1.111996    0.630491   526.469420        17.942927   915.587083
# 1      ...  1.751839    0.124017   320.127526        10.910462   794.277350
# 2      ...  1.670493    0.080322   344.073936        11.726595   840.673617
# 3      ...  1.475847    0.093107   400.057449        13.634603   946.589884
# 4      ...  1.855452    0.272486   346.042245        11.793678   792.296039
# ...    ...       ...         ...          ...              ...          ...
# 51702  ...  1.933569    0.270592   657.307139        14.562931  1408.407648
# 51703  ...  3.124166    1.939505   540.341368        11.971503  1985.435361
# 51704  ...  2.759242    1.195339   759.369097        16.824159  1783.268631
# 51705  ...  1.641598    0.858837  1125.857244        24.943866  1687.895816
# 51706  ...  4.411877    0.352493   167.701907         3.715510   467.340278
#
#        rest_index_norm       lng       lat       City    Period
# 0            20.154890   2.17556  41.39624  Barcelona  Weekdays
# 1            17.484489   2.14906  41.38714  Barcelona  Weekdays
# 2            18.505814   2.15357  41.37859  Barcelona  Weekdays
# 3            20.837357   2.16839  41.37390  Barcelona  Weekdays
# 4            17.440874   2.15238  41.37699  Barcelona  Weekdays
# ...                ...       ...       ...        ...       ...
# 51702        30.685786  12.48137  41.90860       Rome  Weekends
# 51703        43.257820  12.46700  41.89100       Rome  Weekends
# 51704        38.853097  12.46900  41.90100       Rome  Weekends
# 51705        36.775155  12.48342  41.89634       Rome  Weekends
# 51706        10.182211  12.53000  41.86700       Rome  Weekends
#
# [51707 rows x 22 columns]
